# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
# useful webs:
# latex font: https://texblog.org/2012/08/29/changing-the-font-size-in-latex/
# plot marker: https://stackoverflow.com/questions/8409095/matplotlib-set-markers-for-individual-points-on-a-line
# LaTeX for Jupyther: https://www.mathjax.org/

# %%
# import datasets
# One Variable
ex1data1 = pd.read_csv("ex1data1.txt", header=None, names=['cityPopulation', 'foodTruckProfit'])
# Multiple Variables
ex1data2 = pd.read_csv("ex1data2.txt", header=None)
ex1data1.head()
# Out:
#    cityPopulation  foodTruckProfit
# 0          6.1101          17.5920
# 1          5.5277           9.1302
# 2          8.5186          13.6620
# 3          7.0032          11.8540
# 4          5.8598           6.8233

# %%
ex1data1.describe()
# Out:
#        cityPopulation  foodTruckProfit
# count       97.000000        97.000000
# mean         8.159800         5.839135
# std          3.869884         5.510262
# min          5.026900        -2.680700
# 25%          5.707700         1.986900
# 50%          6.589400         4.562300
# 75%          8.578100         7.046700
# max         22.203000        24.147000

# %%
# File info. We have all non-null values. Good
ex1data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# cityPopulation     97 non-null float64
# foodTruckProfit    97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
ex1data2.head()
# Out:
#       0  1       2
# 0  2104  3  399900
# 1  1600  3  329900
# 2  2400  3  369000
# 3  1416  2  232000
# 4  3000  4  539900

# %%
# Starting with only one variable and plotting in a scatter
ex1data1.plot(kind='scatter', x='cityPopulation', y='foodTruckProfit', marker='x', color='r')
plt.xlabel("Population of City in 10,000s")
plt.ylabel("Profit in 10,000s")
plt.show()

# %%
# Calculate correlation
# shows good correlation (more population, more people buy food -> more profit)
print(np.corrcoef(ex1data1.cityPopulation, ex1data1.foodTruckProfit))
# Out:
# [[1.         0.83787323]
#  [0.83787323 1.        ]]

# %% [markdown]
# ### Objective of Linear Regression: minimize the Cost Function
# \begin{equation*}
# \Large
# J(\theta) = \frac{1}{2m} \sum_{n=1}^m \left( h_\theta (x^{(i)}) - y^{(i)} \right)^2
# \end{equation*}

# %% [markdown]
# ### Hypothesis for the linear model
# \begin{equation*}
# \Large
# h_\theta (x) = \theta^Tx = \theta_0 + \theta_1x_1
# \end{equation*}

# %% [markdown]
# ### Gradient Descent
# \begin{equation*}
# \Large
# \theta_j := \theta_j - \alpha\frac{1}{m} \sum_{n=1}^m \left( h_\theta (x^{(i)}) - y^{(i)} \right)x_j^{(i)}
# \end{equation*}

# %%
# Initialize useful variables
theta = np.array([[0],[0]])
iterations = 1500
alpha = 0.01

# %%
# Extract values and initialize the X matrix, with m records
ex1_n=ex1data1.values
m=len(ex1_n[:,1])
# matrix of the data. We add '1' to the 'column' of the one variable (in this case)
X=np.append(np.ones((m,1)), ex1_n[:,0].reshape(m,1), axis=1)
print('The shape of X is: %s rows x %s column/s' % (X.shape[0], X.shape[1]))
# predictor 'column' of the file
y=ex1_n[:,1].reshape(m,1)
print('The shape of y is: %s rows x %s column/s' % (y.shape[0], y.shape[1]))
theta=np.zeros((2,1))
print('The shape of y is: %s rows x %s column/s' % (theta.shape[0], theta.shape[1]))
# Out:
# The shape of X is: 97 rows x 2 column/s
# The shape of y is: 97 rows x 1 column/s
# The shape of y is: 2 rows x 1 column/s

# %%
# define the cost function in a vectorized way
def computeCost(X, y, theta):
    m = len(y)
    J = 0
    # In the course and the formula we multiply theta.transpose x X. But in a vectorized way the following works:
    # Here we multiply a matrix of 97x2 · 2x1. The result will be a vector 'h' of dimensions 97x1.
    h = X.dot(theta)
    # 'h' and 'y' have the same dimensions. Calculate the square error.
    sq_er = (h-y)**2
    # Calculate Cost Function and return it.
    J = 1/(2*m) * np.sum(sq_er)
    return J

# %%
# define the Gradient Descent
def gradientDescent(X, y, theta, alpha, num_iters):
    m = len(y)
    J_history = []
    
    for i in range(num_iters):
        # Here we multiply a matrix of 97x2 · 2x1. The result will be a vector 'h' of dimensions 97x1.
        h = X.dot(theta)
        # 'X' has dimension 97x2 and '(h-y)' 97x1. To multiply, we need to transpose 'X' and we get dimension 2x97.
        # Will do a multiplication of 2x97 · 97x1. The result will have dims of 2x1.
        error = np.dot(X.transpose(),(h - y))
        # Complete the descent including 'aplha' and '1/m'
        descent = alpha * 1/m * error
        # Update the theta vector
        theta -= descent
        # Compute Cost Function
        J_history.append(computeCost(X,y,theta))
    return theta, J_history

# %%
# Compute Cost Function for theta0 = 0; theta1 = 0
computeCost(X,y,theta)
# Out:
# 32.072733877455676

# %%
# Compute Cost Function for theta0 = -1; theta1 = 2
computeCost(X,y,np.array([[-1],[2]]))
# Out:
# 54.24245508201238

# %%
# Running Gradient Descent
theta,J_history = gradientDescent(X, y, theta, alpha, iterations)
print("h(x) = "+str(round(theta[0,0],2))+" + "+str(round(theta[1,0],2))+"x1")
# a if condition else b
print('The parameters of the hypothesis will be: h(x) = %s %s %sx1' % (str(round(theta[0,0],2)), '-' if theta[1,0] < 0 else '+' , str(round(theta[1,0],2))))
# Out:
# h(x) = -3.63 + 1.17x1
# The parameters of the hypothesis will be: h(x) = -3.63 + 1.17x1

# %%
# Using the hypothesis: h(x) = -3.63 + 1.17x1 will predict for 35000 (3.5)
predict1 = np.dot(theta.transpose(),np.array([1,3.5]))
print('For a 35000 population the price will be: $%0.4f' % (predict1[0]*10000))
# Out:
# For a 35000 population the price will be: $4519.7679

# %%
# Using the hypothesis: h(x) = -3.63 + 1.17x1 will predict for 70000 (7)
predict2 = np.dot(theta.transpose(), np.array([1,7]))
print('For a 70000 population the price will be: $%0.4f' % (predict2[0]*10000))
# Out:
# For a 70000 population the price will be: $45342.4501

# %%
# Plot the fitted line after theta vector
# Function
f = lambda x: theta[0] + theta[1]*x
x = np.array(ex1data1['cityPopulation'])
y = [f(i) for i in x]
ex1data1.plot(kind='scatter', x='cityPopulation', y='foodTruckProfit', marker='x', color='r')
plt.xlabel("Population of City in 10,000s")
plt.ylabel("Profit in 10,000s")
plt.plot(x, y, c="blue")
plt.show()

# %%
# Plot cost vs iterations for one variable
# Seems good as it decreases with iterations
plt.plot(np.arange(iterations),J_history)
plt.xlabel("iterations")
plt.ylabel("Cost J(0)")
plt.show()

# %%
# Generate Surface plot
# Grid over which we will calculate J
theta0_vals = np.linspace(-10, 10, 100)
theta1_vals = np.linspace(-1, 4, 100)

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

for i in range(len(theta0_vals)):
    for j in range(len(theta1_vals)):
        t = np.array([theta0_vals[i], theta1_vals[j]])
        J_vals[i,j] = computeCost(X,y,t)
#J_vals = J_vals.transpose()

fig = plt.figure(figsize=(14, 5))
fig.subplots_adjust(wspace=0.3)
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122)

theta0, theta1 = np.meshgrid(theta0_vals, theta1_vals)

# Surface plot:
ax1.set_title('Surface plot')
ax1.plot_surface(theta1, theta0, J_vals.T, cmap='jet', rstride=3, cstride=3, antialiased=True)
ax1.view_init(elev=20, azim=318)
ax1.set_xlabel(r'$\theta_1$', labelpad=8)
ax1.set_xlim(4,-1)
ax1.set_ylabel(r'$\theta_0$', labelpad=8)
ax1.set_yticks(np.linspace(-10, 10, 5))
ax1.set_zlabel(r'$J(\theta)$', labelpad=8);

# Contour plot:
ax2.set_title('Contour plot, showing minimum')
#ax2.contour(theta0, theta1, J_vals.T, np.logspace(-2, 3, 20),  cmap='jet')
ax2.contour(theta0, theta1, J_vals.T, cmap='jet')
ax2.scatter(theta[0], theta[1], marker='x', color='r', s=40)
ax2.set_xlabel(r'$\theta_0$')
ax2.set_ylabel(r'$\theta_1$')
ax2.set_yticks(np.arange(-1,4.5,0.5));

# %% [markdown]
# ## Linear regression with multiple variables

# %% [markdown]
# ### Feature Normalization

# %%
# Change column names
ex1data2.columns = ['size', 'bedrooms', 'price']
ex1data2.head()
# Out:
#    size  bedrooms   price
# 0  2104         3  399900
# 1  1600         3  329900
# 2  2400         3  369000
# 3  1416         2  232000
# 4  3000         4  539900

# %%
# Calculate mean for every column
meanSize = ex1data2['size'].mean()
meanBedr = ex1data2['bedrooms'].mean()
meanPrice = ex1data2['price'].mean()
# Normalize with apply()
def norm(x):
    return (x - x.mean())/x.std()
def featureNormalization(X):
    """
    Take in numpy array of X values and return normalize X values,
    the mean and standard deviation of each feature
    """
    mean=np.mean(X,axis=0)
    std=np.std(X,axis=0)
    
    X_norm = (X - mean)/std
    
    return X_norm , mean , std

# %%
alpham = 0.01
num_itersm = 400
ex2_n=ex1data2.values
mm = len(ex2_n[:,-1])
Xm = ex2_n[:,0:2].reshape(mm, 2)
Xm, mu, sigma = featureNormalization(Xm)
Xm = np.c_[np.ones((mm,1)), Xm]
ym = ex2_n[:,-1].reshape(mm,1)
thetam = np.zeros((3,1))
computeCost(Xm,ym,thetam)
thetam, J_historym = gradientDescent(Xm, ym, thetam, alpham, num_itersm)
print(thetam)
# Out:
# [[334302.06399328]
#  [ 99411.44947359]
#  [  3267.01285407]]

# %%
#plt.plot(np.arange(num_itersm),J_historym)
plt.plot(J_historym)
plt.xlabel("iterations")
plt.ylabel("$J(\Theta)$")
plt.show()

# %%
# Choose/view the best 'alpha' value
alphaSel = [0.3, 0.1, 0.03, 0.01, 0.003]
figEx = plt.figure(figsize=(10,5))
ax = figEx.add_subplot(111)
ax.set_title('Cost Function vs Iterations')
for n in alphaSel:
    thetaTmp = np.zeros((3,1))
    thetaTmp, J_tmp = gradientDescent(Xm, ym, thetaTmp, n, num_itersm)
    plt.plot(J_tmp,label=n)
    plt.xlabel("iterations")
    plt.ylabel("$J(\Theta)$")

#plt.gca().legend(alphaSel)  # this is a version for legend display
ax.legend(loc='best') # this is a better version for legend display
plt.show()

# %%
# Predict for house size and number of bedrooms, a cost for the house with alpha=0.01
size = (1650 - mu[0])/sigma[0]
bedrooms = (3 - mu[1])/sigma[1]
predict3 = np.dot(thetam.transpose(), np.array([1,size, bedrooms]))
print ('A 3 bedroom / 1650 sqft house will cost $%0.2f' % predict3)
# Out:
# A 3 bedroom / 1650 sqft house will cost $289221.55

# %%
# Predict for house size and number of bedrooms, a cost for the house with alpha=0.01
size = (1650 - mu[0])/sigma[0]
bedrooms = (3 - mu[1])/sigma[1]
thetaUlt = np.zeros((3,1))
thetaUlt, J_tmp = gradientDescent(Xm, ym, thetaUlt, 0.03, 500)
predictUlt = np.dot(thetaUlt.transpose(), np.array([1,size, bedrooms]))
print ('A 3 bedroom / 1650 sqft house will cost $%0.2f' % predictUlt)
# Out:
# A 3 bedroom / 1650 sqft house will cost $293097.99

# %% [markdown]
# ### Normal Equation

# %%
# Use the Normal Equation
thetaNorm = np.linalg.pinv((Xm.transpose().dot(Xm))).dot(Xm.transpose()).dot(ym)
print(thetaNorm)
predict4 = np.dot(thetaNorm.transpose(), np.array([1,size,bedrooms]))
print ('A 3 bedroom / 1650 sqft house will cost $%0.2f using the Normal Equation' % predict4)
# Out:
# [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
# A 3 bedroom / 1650 sqft house will cost $293081.46 using the Normal Equation
